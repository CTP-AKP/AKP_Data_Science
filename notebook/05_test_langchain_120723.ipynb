# %% [markdown]
# ## Introduction
# - I basically followed through the LangChain course on deep learning ai
# - working on my project
# - https://learn.deeplearning.ai/langchain-chat-with-your-data/lesson/4/vectorstores-and-embedding

# %% [markdown]
# ### Data visualization component
# - I tried to deploy my visualization tool on game data
# - deployed on Huggingface
# - the Langchain component part is not yet deployed
# - https://huggingface.co/spaces/po5302006/ForcaSteam

# %%
# %%cmd
# where python
# python --version
# pip --version
# unstructured --version
# sentence-transformers --version
# Out:
# Microsoft Windows [Version 10.0.22621.2715]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\po530\Desktop>where python
# C:\Users\po530\anaconda3\python.exe
# C:\Users\po530\AppData\Local\Programs\Python\Python310\python.exe
# C:\Users\po530\AppData\Local\Microsoft\WindowsApps\python.exe
# C:\msys64\mingw64\bin\python.exe
#
# C:\Users\po530\Desktop>python --version
# Python 3.11.5
#
# C:\Users\po530\Desktop>pip --version
# pip 23.3 from C:\Users\po530\anaconda3\Lib\site-packages\pip (python 3.11)
#
# C:\Users\po530\Desktop>unstructured --version
# 'unstructured' is not recognized as an internal or external command,
# operable program or batch file.
# C:\Users\po530\Desktop>sentence-transformers --version
# 'sentence-transformers' is not recognized as an internal or external command,
# operable program or batch file.
# C:\Users\po530\Desktop>

# %%
# %%cmd
# pip install openai
# pip install pypdf
# pip install unstructured
# pip install tiktoken
# pip install sentence-transformers
# pip install chromadb
# Out:
# Microsoft Windows [Version 10.0.22621.2715]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\po530\Desktop>pip install openai
# ...
#
# C:\Users\po530\Desktop>pip install pypdf
# ...
#
# C:\Users\po530\Desktop>pip install unstructured
# ...
#
# C:\Users\po530\Desktop>pip install tiktoken
# ...
#
# C:\Users\po530\Desktop>pip install sentence-transformers
# ...
#
# C:\Users\po530\Desktop>pip install chromadb
# ...
#   Using cached chromadb-0.4.18-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached fastapi-0.104.1-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached posthog-3.1.0-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached opentelemetry_api-1.21.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.21.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached opentelemetry_instrumentation_fastapi-0.42b0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached opentelemetry_sdk-1.21.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
# ...

# %%
import os
import sys
import openai
from langchain.chat_models import ChatOpenAI

# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %%
os.environ['OPENAI_API_KEY'] = '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'
llm_model = "gpt-3.5-turbo"

# %%
chat = ChatOpenAI(temperature=0.0, model=llm_model)
chat
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x00000197C182CDD0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x00000197C2816E90>, temperature=0.0, openai_api_key='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', openai_proxy='')

# %% [markdown]
# ### Langchain template string

# %%
template_string = """Translate the text \
that is delimited by triple backticks \
into a style that is {style}. \
text: ```{text}```
"""

# %%
from langchain.prompts import ChatPromptTemplate
prompt_template = ChatPromptTemplate.from_template(template_string)

# %%
prompt_template.messages[0].prompt
# Out:
# PromptTemplate(input_variables=['style', 'text'], template='Translate the text that is delimited by triple backticks into a style that is {style}. text: ```{text}```\n')

# %%
prompt_template.messages[0].prompt.input_variables
# Out:
# ['style', 'text']

# %%
customer_style = """American English \
in a calm and respectful tone
"""

# %%
customer_email = """
Arrr, I be fuming that me blender lid \
flew off and splattered me kitchen walls \
with smoothie! And to make matters worse, \
the warranty don't cover the cost of \
cleaning up me kitchen. I need yer help \
right now, matey!
"""

# %%
customer_messages = prompt_template.format_messages(
                    style=customer_style,
                    text=customer_email)

# %%
print(type(customer_messages))
print(type(customer_messages[0]))
print(customer_messages[0])
# Out:
# <class 'list'>
# <class 'langchain_core.messages.human.HumanMessage'>
# content="Translate the text that is delimited by triple backticks into a style that is American English in a calm and respectful tone\n. text: ```\nArrr, I be fuming that me blender lid flew off and splattered me kitchen walls with smoothie! And to make matters worse, the warranty don't cover the cost of cleaning up me kitchen. I need yer help right now, matey!\n```\n"

# %%
customer_response = chat(customer_messages)
print(customer_response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 customer_response = chat(customer_messages)
#       2 print(customer_response.content)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:632, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     625 def __call__(
#     626     self,
#     627     messages: List[BaseMessage],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> BaseMessage:
# --> 632     generation = self.generate(
#     633         [messages], stop=stop, callbacks=callbacks, **kwargs
#     634     ).generations[0][0]
#     635     if isinstance(generation, ChatGeneration):
#     636         return generation.message
#
# ...

# %% [markdown]
# ### Langchain data loader

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.document_loaders.csv_loader import UnstructuredCSVLoader

# sys.path.append('../..')
# loader = PyPDFLoader("docs/cs229_lectures/MachineLearning-Lecture01.pdf")

# %%
loader = CSVLoader(
    file_path="./data/name_content.csv",
    csv_args={
        "delimiter": ",",
        "quotechar": '"',
        "fieldnames": ["name", "content"],
    },
)

data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\langchain\document_loaders\csv_loader.py:70, in CSVLoader.load(self)
#      69     with open(self.file_path, newline="", encoding=self.encoding) as csvfile:
# ---> 70         docs = self.__read_file(csvfile)
#      71 except UnicodeDecodeError as e:
#
# File ~\anaconda3\Lib\site-packages\langchain\document_loaders\csv_loader.py:94, in CSVLoader.__read_file(self, csvfile)
#      93 csv_reader = csv.DictReader(csvfile, **self.csv_args)  # type: ignore
# ---> 94 for i, row in enumerate(csv_reader):
#      95     try:
#
# File ~\anaconda3\Lib\csv.py:111, in DictReader.__next__(self)
#     110     self.fieldnames
# --> 111 row = next(self.reader)
#     112 self.line_num = self.reader.line_num
#
# File ~\anaconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
# ...

# %%
loader = CSVLoader(file_path="./data/test.csv")
data = loader.load()
print(data)
print(data[1])
print(len(data))
# Out:
# [Document(page_content='name: game\ncontent: this is a test', metadata={'source': './data/test.csv', 'row': 0}), Document(page_content='name: game2\ncontent: another test', metadata={'source': './data/test.csv', 'row': 1}), Document(page_content='name: notGame\ncontent: test3', metadata={'source': './data/test.csv', 'row': 2})]
# page_content='name: game2\ncontent: another test' metadata={'source': './data/test.csv', 'row': 1}
# 3

# %%
loader = UnstructuredCSVLoader(
    file_path="./data/name_content.csv", mode="elements"
)
docs = loader.load()

# %%
len(docs)
# Out:
# 1

# %%
print(docs[0].metadata["text_as_html"])
# print(docs[0])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# df.to_csv(index=False)
# df.to_csv('data/output.csv', index=False)

# %% [markdown]
# ### Dataframe loader
# - I failed to load the dataset that was scrapped from wikipedia

# %%
import pandas as pd
df = pd.read_csv('./data/name_content.csv')
df.dtypes
print(df.head(1)['content'])
df.head()
# Out:
# 0    A dogfight, or dog fight, is an aerial battle ...
# Name: content, dtype: object
#                       name                                            content
# 0                 Dogfight  A dogfight, or dog fight, is an aerial battle ...
# 1        Vanguard Princess  Vanguard Princess (ヴァンガードプリンセス, Vangaado Purin...
# 2      Deadfall Adventures  Deadfall Adventures is an action-adventure vid...
# 3  Reigns: Game of Thrones  Reigns: Game of Thrones is a 2018 strategy gam...
# 4                  Far Cry  Far Cry is an anthology franchise of first-per...

# %%
from langchain.document_loaders import DataFrameLoader
loader = DataFrameLoader(df, page_content_column="content")
pages = loader.load()

# %%
page = pages[0]
print(page)
# Out:
# page_content='A dogfight, or dog fight, is an aerial battle between fighter aircraft conducted at close range. Modern terminology for air-to-air combat is air combat manoeuvring (ACM), which refers to tactical situations requiring the use of individual basic fighter maneuvers (BFM) to attack or evade one or more opponents. This differs from aerial warfare, which deals with the strategy involved in planning and executing various missions.Dogfighting first occurred during the Mexican Revolution in 1913, shortly after the invention of the airplane. It was a component in every major war, though with steadily declining frequency, until the end of the Cold War in the early 1990s. Since then, longer-range weapons such as beyond-visual-range missiles have made dogfighting largely obsolete.\n\n' metadata={'name': 'Dogfight'}

# %% [markdown]
# ### Text splitter

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain.text_splitter import TokenTextSplitter

# %%
text_splitter = TokenTextSplitter(chunk_size=1, chunk_overlap=0)
text1 = "foo bar bazzyfoo"
text_splitter.split_text(text1)
# Out:
# ['foo', ' bar', ' b', 'az', 'zy', 'foo']

# %%
text_splitter = TokenTextSplitter(chunk_size=10, chunk_overlap=0)
docs = text_splitter.split_documents(pages)

# %%
print(len(pages))
print(len(docs))
print(docs[2])
print(docs[2].metadata)
# Out:
# 3550
# 4
# page_content=' for the game, with new game mechanics including wildlife' metadata={'name': 'Scrap Mechanic'}
# {'name': 'Scrap Mechanic'}

# %%
r_splitter = RecursiveCharacterTextSplitter(
    chunk_size=150,
    chunk_overlap=0,
    separators=["\n\n", "\n", "(?<=\. )", " ", ""]
)
r_docs = r_splitter.split_documents(pages)

# %%
print(len(pages))
print(len(r_docs))
print(r_docs[2])
print(r_docs[2].metadata)
# Out:
# 3550
# 21738
# page_content='more opponents. This differs from aerial warfare, which deals with the strategy involved in planning and executing various missions.Dogfighting first' metadata={'name': 'Dogfight'}
# {'name': 'Dogfight'}

# %% [markdown]
# ### Embedding

# %%
from sentence_transformers import SentenceTransformer
sentr_model = SentenceTransformer('all-MiniLM-L6-v2')
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
embedding = OpenAIEmbeddings()
# embedding1 = embedding.embed_query(sentence1)
# embedding2 = embedding.embed_query(sentence2)
# embedding3 = embedding.embed_query(sentence3)

# %% [raw]
# sentence1 = "i like dogs"
# sentence2 = "i like canines"
# sentence3 = "the weather is ugly outside"
# embedding1 = sentr_model.encode(sentence1)
# embedding2 = sentr_model.encode(sentence2)

# %%
import numpy as np
np.dot(embedding1, embedding2)
# Out:
# 0.91516465

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = 'docs/chroma/'

# %%
# %%cmd
# rmdir -rf ./docs/chroma
# Out:
# Microsoft Windows [Version 10.0.22621.2715]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\po530\Desktop>rmdir -rf ./docs/chroma
# Invalid switch - "docs".
# C:\Users\po530\Desktop>

# %%
vectordb = Chroma.from_documents(
    documents=docs,
    embedding=embedding,
    persist_directory=persist_directory
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 vectordb = Chroma.from_documents(
#       2     documents=docs,
#       3     embedding=embedding,
#       4     persist_directory=persist_directory
#       5 )
#
# File ~\anaconda3\Lib\site-packages\langchain\vectorstores\chroma.py:771, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     769 texts = [doc.page_content for doc in documents]
#     770 metadatas = [doc.metadata for doc in documents]
# --> 771 return cls.from_texts(
#     772     texts=texts,
#     773     embedding=embedding,
#     774     metadatas=metadatas,
#     775     ids=ids,
#     776     collection_name=collection_name,
#     777     persist_directory=persist_directory,
#     778     client_settings=client_settings,
# ...

# %%
vectordb = Chroma.from_documents(
    documents=docs,
    embedding=sentr_embedding_function,
    persist_directory=persist_directory
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 vectordb = Chroma.from_documents(
#       2     documents=docs,
# ----> 3     embedding=sentr_embedding_function,
#       4     persist_directory=persist_directory
#       5 )
#
# NameError: name 'sentr_embedding_function' is not defined

# %%
db = Chroma.from_documents(docs, embedding_function)

# %%
# query = "What did the president say about Ketanji Brown Jackson"
# query = "What shooting is similar to Counter-Strike:global offensive?"
query = "What game has animals?"
docs = db.similarity_search(query)

# %%
print(docs[0].page_content)
print(docs[0])
# Out:
# ) are animals from a zoo.
# The game
# page_content=') are animals from a zoo.\nThe game' metadata={'name': 'Wacky Wheels'}

# %% [markdown]
# ### Dataframe view

# %%
import pandas as pd

# %%
df_ax = pd.read_csv('../data/join_02.csv')
df_ax = df_ax[['gamename', 'date', 'avg']].sort_values(by='avg').reset_index()
df_ax.head()
# Out:
#    index                                 gamename        date  avg
# 0  30011                              LUFTRAUSERS  2013-06-01  0.0
# 1  52075  THE KING OF FIGHTERS XIII STEAM EDITION  2012-10-01  0.0
# 2  52074  THE KING OF FIGHTERS XIII STEAM EDITION  2012-11-01  0.0
# 3  23001                                Gone Home  2013-03-01  0.0
# 4   8198              Car Mechanic Simulator 2018  2017-06-01  0.0

# %%
# df_ax = df_ax.groupby('gamename').mean('avg')
# df_ax
gamenames = df_ax.gamename.unique()
df_ax = pd.DataFrame(gamenames, columns=['gamename'])
df_ax.head(6)
# Out:
#                                   gamename
# 0                              LUFTRAUSERS
# 1  THE KING OF FIGHTERS XIII STEAM EDITION
# 2                                Gone Home
# 3              Car Mechanic Simulator 2018
# 4                      The Stanley Parable
# 5              What Remains of Edith Finch

# %%
df_ax = df_ax.loc[5:10]
df_ax
# Out:
#                        gamename
# 5   What Remains of Edith Finch
# 6                      Warframe
# 7                Darksiders III
# 8             Heroes & Generals
# 9                    Broken Age
# 10           Night in the Woods

# %%
import plotly.express as px
df = pd.read_csv('../data/join_02.csv')
df.columns
# Out:
# Index(['gamename', 'year', 'month', 'avg', 'gain', 'peak', 'avg_peak_perc',
#        'date', 'release_date', 'required_age', 'price', 'dlc_count', 'windows',
#        'mac', 'linux', 'metacritic_score', 'positive', 'negative',
#        'developers', 'publishers', 'average_playtime_forever',
#        'average_playtime_two_weeks', 'median_playtime_forever',
#        'median_playtime_two_weeks', 'multi_player', 'pvp', 'co-op',
#        'genre_action', 'genre_adventure', 'genre_casual',
#        'genre_sexual_content', 'genre_strategy', 'genre_sports',
#        'genre_racing', 'genre_rpg', 'genre_simulation', 'indie', 'full_audio',
#        'full_controller_support', 'age_0_plus', 'age_13_plus', 'age_18_plus'],
#       dtype='object')

# %%
# names = 'price'
# fig_ratio = px.pie(df, names=names)
# fig_ratio.show()

# %%
labels = 'price'
other_limit = 80
df_pie = df[['gamename', labels]]
df_pie[f'{labels}_pie'] = df_pie[labels]
# Out:
# C:\Users\po530\AppData\Local\Temp\ipykernel_13184\2066648411.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pie.loc[df[labels] > other_limit, f'{labels}_pie'] = f'Other_{labels}'
df_pie.head()

# %%
value = 0.99
len(df[df[labels] == value])
# Out:
# 842

# %%
for value in df[labels].unique():
    df_pie.loc[len(df[df[labels] == value]) > other_limit, f'{labels}_pie'] = f'Other_{labels}'
df_pie.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 2
#       1 for value in df[labels].unique():
# ----> 2     df_pie.loc[len(df[df[labels] == value]) > other_limit, f'{labels}_pie'] = f'Other_{labels}'
#       3 df_pie.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:885, in _LocationIndexer.__setitem__(self, key, value)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1795, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1791 for i, idx in enumerate(indexer):
#    1792     if isinstance(idx, dict):
#    1793         # reindex the axis to the new value
#    1794         # and set inplace
# ...

# %%
# df_p[labels] = pd.DataFrame(labels:df[labels].unique())
value = 0.99
len(df[df[labels] == value])/len(df)
# Out:
# 0.013186331318319918

# %%
values = []
index = df[labels].unique().tolist()
for idx, value in enumerate(index):
    count = len(df[df[labels] == value])
    values.append(count)
    if(count/len(df) < 0.02): index[idx] = 'Other'

# %%
labels = 'price' 

df_p = pd.DataFrame(data = values,  
                  index = index,  
                  columns = ['counts']) 
df_p = df_p.reset_index().rename(columns={'index':labels})
df_p.head()
# Out:
#    price  counts
# 0  Other      84
# 1   9.99    9604
# 2   4.99    2691
# 3  Other     301
# 4  24.99    1886

# %%
fig = px.pie(df_p, values='counts', names=labels)
fig.show()
# Out:
# <div>                            <div id="533c8904-0e6d-41ed-ab87-8496cc433b92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("533c8904-0e6d-41ed-ab87-8496cc433b92")) {                    Plotly.newPlot(                        "533c8904-0e6d-41ed-ab87-8496cc433b92",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"price=%{label}<br>counts=%{value}<extra></extra>","labels":["Other",9.99,4.99,"Other",24.99,14.99,"Other",29.99,19.99,0.0,39.99,"Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","Other","O
# ...

# %%
fig = px.pie(df_pie, values=f'{labels}_pie', names=labels)
fig.show()
# Out:
# <div>                            <div id="04c0cbbe-1e52-4e0e-b5b0-8d999219b87f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04c0cbbe-1e52-4e0e-b5b0-8d999219b87f")) {                    Plotly.newPlot(                        "04c0cbbe-1e52-4e0e-b5b0-8d999219b87f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"price=%{label}<br>price_pie=%{value}<extra></extra>","labels":[1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.74,1.
# ...

# %%
# df_pie = df_pie[df_pie['price'] == 'new_price'].copy()
# df_pie['new_price'] = df_pie['price'].values
# df_pie.loc[:,'new_price'] = df_pie['price'].copy()

# %%
df_pie[f'{labels}_pie'] = df_pie[labels] 
df_pie.loc[df[labels] > other_limit, f'{labels}_pie'] = f'Other_{labels}' # Represent only large
df_pie

# %%
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
embedding = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
from langchain.vectorstores import Chroma

# %%
# load from disk
db = Chroma(
    persist_directory="../data/docs/chroma", 
    embedding_function=embedding
)

# %%
query = "What game similar to CSGO, besides CSGO itself?"
docs = db.similarity_search(query, k=3)
print(docs[0].page_content)
print(docs[0].metadata)
# Out:
# DRPG. It has all the facets one would expect from a game of its genre and manages to implement those features effectively." Chris Carter of
# {'name': 'Operation Abyss: New Tokyo Legacy'}

# %%
assistant_response = "1. game1\n2. game2\n3. game3"
r.rstrip('\n').split() + ['\n']
# Out:
# ['1.', 'game1', '2.', 'game2', '3.', 'game3', '\n']

# %%
words = []
for line in assistant_response.splitlines():
    for word in line.split() : words.append(word)
    words.append('\n')
words = words[0:-1]
words
# Out:
# ['1.', 'game1', '\n', '2.', 'game2', '\n', '3.', 'game3']
